# %%
print("Hello World")
# Out:
# Hello World

# %%
import openai
import os 

api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    api_key = input("Enter your OpenAI API key: ").strip()
    os.environ["OPENAI_API_KEY"] = api_key
    if not api_key:
        raise ValueError("No API key provided")

# %%
import openai
import os 

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of France?"},
        {"role": "user", "content": "can you print 10 randomn words?"},
    ]
)

print(response.choices[0].message.content)

# %%
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    api_key = input("Enter your Google API key: ").strip()
    os.environ["GOOGLE_API_KEY"] = api_key
    if not api_key:
        raise ValueError("No API key provided")

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))
response = gemini_client.models.generate_content(
    model="gemini-1.5-flash",
    contents=["You are helpful assistant", "What is the capital of France?", "can you print 15 randomn words?"]
)

print(response.text)

# %%
api_key = os.getenv("GROQ_API_KEY")
if not api_key:
    api_key = input("Enter your Groq API key: ").strip()
    os.environ["GROQ_API_KEY"] = api_key
    if not api_key:
        raise ValueError("No API key provided")

# %%
import os

from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of France?"},
        {"role": "user", "content": "can you print 20 randomn words?"},
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Space
# 2. Helicopter
# 3. Caramel
# 4. Diamond
# 5. Coffee
# 6. Bicycle
# 7. Banana
# 8. Guitar
# 9. Snowflake
# 10. Perfume
# 11. Llama
# 12. Starfish
# 13. Pineapple
# 14. Football
# 15. Violin
# 16. Butterfly
# 17. Bicycle
# 18. Submarine
# 19. Harmonica
# 20. Tornado
